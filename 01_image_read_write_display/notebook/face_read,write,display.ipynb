# %%
import cv2

# %%
import numpy as np

# %%
input= cv2.imread(r"C:\Users\ASUS\Downloads\manas profile.jpeg")

# %%
input
# Out:
# array([[[186, 197, 201],
#         [186, 197, 201],
#         [186, 197, 201],
#         ...,
#         [179, 191, 197],
#         [179, 191, 197],
#         [180, 192, 198]],
#
#        [[187, 198, 202],
#         [187, 198, 202],
#         [187, 198, 202],
#         ...,
#         [179, 191, 197],
#         [179, 191, 197],
#         [180, 192, 198]],
#
#        [[187, 198, 202],
#         [187, 198, 202],
#         [187, 198, 202],
#         ...,
#         [179, 191, 197],
#         [179, 191, 197],
#         [180, 192, 198]],
#
#        ...,
#
#        [[ 69,  65,  64],
#         [ 73,  69,  68],
#         [ 79,  75,  74],
#         ...,
#         [ 95,  91,  90],
#         [ 87,  83,  82],
#         [ 85,  81,  80]],
#
#        [[ 88,  83,  82],
#         [ 90,  85,  84],
#         [ 94,  89,  88],
#         ...,
#         [ 99,  95,  94],
#         [ 87,  83,  82],
#         [ 89,  85,  84]],
#
#        [[104,  99,  98],
#         [103,  98,  97],
#         [105, 100,  99],
# ...

# %%
cv2.imshow("input",input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print("height of image is:",input.shape[0],'pixels')
print("width of image is:",input.shape[1],'pixels')
# Out:
# height of image is: 1356 pixels
# width of image is: 1017 pixels

# %%
cv2.imwrite(r"C:\Users\ASUS\Downloads\manas profile.jpeg",input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'd:\\python\\compter vision'
